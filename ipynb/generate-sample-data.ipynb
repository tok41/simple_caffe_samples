# %%
import os, sys
import numpy as np
import pandas as pd

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
rand_test = np.random.randn(1000)
plt.hist(rand_test, bins=30)
# Out:
# (array([  3.,   2.,   4.,   5.,  13.,  13.,  16.,  28.,  43.,  38.,  58.,
#          57.,  75.,  72.,  88.,  71.,  71.,  59.,  63.,  48.,  49.,  37.,
#          26.,  21.,  19.,   9.,   3.,   4.,   2.,   3.]),
#  array([-2.75647066, -2.56855086, -2.38063106, -2.19271126, -2.00479146,
#         -1.81687167, -1.62895187, -1.44103207, -1.25311227, -1.06519247,
#         -0.87727268, -0.68935288, -0.50143308, -0.31351328, -0.12559348,
#          0.06232632,  0.25024611,  0.43816591,  0.62608571,  0.81400551,
#          1.00192531,  1.18984511,  1.3777649 ,  1.5656847 ,  1.7536045 ,
#          1.9415243 ,  2.1294441 ,  2.3173639 ,  2.50528369,  2.69320349,
#          2.88112329]),
#  <a list of 30 Patch objects>)

# %%
(np.abs(rand_test) < 1.0).mean()
# Out:
# 0.68300000000000005

# %%
# y = 3.0*x_1 + 2.0*x_2 + 4.0
N = 1000

# ノイズパラメータ
mu = 0.0
sig = 0.1

# data
x_1 = np.random.rand(N)
# noise
ran = np.random.randn(N)*sig+mu

data = 3.* x_1 + 4.0 + ran

plt.scatter(x_1, data, alpha=0.3)

# %%
# ノイズパラメータ
mu = 0.0
sig = 0.1
# モデルパラメータ
alpha = 2.0
beta = 4.0
N = 100

x = np.arange(0, 1.0, 0.2)
target = np.ones((N, len(x))) * x
y_t = target * alpha + beta
ran = np.random.randn(target.shape[0], target.shape[1]) * sig + mu
y = y_t + ran
#y

# %%
N_all = target.shape[0] * target.shape[1]
x_line = np.reshape(target, N_all)
y_t_line = np.reshape(y_t, N_all)
y_line = np.reshape(y, N_all)

plt.scatter(x_line, y_line, alpha=0.3)

# %%
x
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8])
